# %%
print("hello")

# %%
arr = [1,2,3,4,5]

# %%
def square(x):
    return x**2

# %%
list(map(square,arr))

# %%
def add(x,y):
    return x + y

# %%
from functools import reduce
arr = [1,2,3,4,5]
reduce(add,arr)

# %%
add = lambda x,y: x + y

# %%
from functools import reduce
arr = [1,2,3,4,5]
reduce(add,arr)

# %%
list(map(lambda pair: pair[0]+pair[1] if pair[0]%2==0 and pair[1]%2==0 else pair[0]*pair[1] if pair[0]%2==1 and pair[1]%2==1 else abs(pair[0]-pair[1]),data))

# %%
pair[0]+pair[1] if pair[0]%2==0 and pair[1]%2==0 else pair[0]*pair[1] if pair[0]%2==1 and pair[1]%2==1 else abs(pair[0]-pair[1])
